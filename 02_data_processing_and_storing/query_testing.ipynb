# %% [markdown]
# **Load dependencies**

# %%
import pg8000

# %% [markdown]
# **Connect to database**

# %%
#basic query syntax

config = {
    "database": "postgres",
    "user": "postgres",
    "password": "XXXXXXXXXXXXXXXXXXXXXX",
    "host": "db-group1.crhso94tou3n.eu-west-2.rds.amazonaws.com",
    "port": 5432,
}


class PGWrapper:
    def __init__(self, config, autocommit=True):
        self.__autocommit = autocommit
        self.__config = config

    def __enter__(self):
        return self.connect()

    def __exit__(self, type, value, traceback):
        self.close()

    def connect(self):
        self.cnx = pg8000.connect(**self.__config)
        self.cnx.autocommit = self.__autocommit
        self.cursor = self.cnx.cursor()
        return self

    def close(self):
        try:
            self.cursor.close()
            self.cnx.close()
        except Exception:
            pass

    def query(self, sql, parameters=tuple()):
        self.cursor.execute(sql, parameters)
        try:
            results = self.cursor.fetchall()
            return results
        except:
            return

    def query_as_list_of_dicts(self, sql, parameters=tuple()):
        self.cursor.execute(sql, parameters)
        results = []
        if self.cursor.description:
            cols = [h[0] for h in self.cursor.description]
            for row in self.cursor.fetchall():
                results.append({a: b for a, b in zip(cols, row)})
        return results

    def commit(self):
        self.cnx.commit()

    def rollback(self):
        self.cnx.rollback()


db_connection=PGWrapper(config)

db_connection.connect()

results= db_connection.query("SELECT * FROM schema_housing.zoopla")
print(results)



#results= db_connection.query("SELECT * FROM website")
#print(results)
# Out:
# ([Decimal('58012738'), 'https://www.zoopla.co.uk//for-sale/details/58012738/?search_identifier=41c22f378285754a0510de9cf512ccae', Decimal('940000'), Decimal('2.0'), Decimal('2.0'), Decimal('1.0'), 'Putney Wharf, 18 Brewhouse Lane, Putney, London SW15', Decimal('0.2'), 'Putney Pier'], [Decimal('52140040'), 'https://www.zoopla.co.uk//for-sale/details/52140040/?search_identifier=41c22f378285754a0510de9cf512ccae', Decimal('3595000'), Decimal('3.0'), Decimal('3.0'), None, 'Biddulph Road, London W9', Decimal('0.1'), 'Maida Vale'], [Decimal('58012696'), 'https://www.zoopla.co.uk//for-sale/details/58012696/?search_identifier=41c22f378285754a0510de9cf512ccae', Decimal('160000'), Decimal('1.0'), None, None, 'Kings Drive, Wembley HA9', Decimal('0.4'), 'Wembley Park'], [Decimal('58012677'), 'https://www.zoopla.co.uk//for-sale/details/58012677/?search_identifier=41c22f378285754a0510de9cf512ccae', Decimal('780000'), Decimal('4.0'), Decimal('2.0'), Decimal('3.0'), 'Falmouth Gardens, London IG4', Decimal('0.4'), 'Redbridge'], [Decimal('58012654'), 'https://www.zoopla.co.uk//for-sale/details/58012654/?search_identifier=41c22f378285754a0510de9cf512ccae', Decimal('225000'), Decimal('1.0'), Decimal('1.0'), Decimal('1.0'), 'Beadles Parade, Rainham Road South, Dagenham RM10', Decimal('0.2'), 'Dagenham East'], [Decimal('58012605'), 'https://www.zoopla.co.uk//for-sale/details/58012605/?search_identifier=41c22f378285754a0510de9cf512ccae', Decimal('450000'), Decimal('2.0'), Decimal('1.0'), Decimal('1.0'), 'Longcourt Mews, Wanstead E11', Decimal('0.6'), 'South Woodford'], [Decimal('58012518'), 'https://www.zoopla.co.uk//for-sale/details/58012518/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('2295000'), Decimal('2.0'), Decimal('2.0'), Decimal('1.0'), 'Palace Court, London W2', Decimal('0.2'), 'Bayswater'], [Decimal('58012520'), 'https://www.zoopla.co.uk//for-sale/details/58012520/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('480000'), Decimal('1.0'), Decimal('1.0'), Decimal('1.0'), 'Gloucester Terrace, Bayswater, London W2', Decimal('0.1'), 'Royal Oak'], [Decimal('58012488'), 'https://www.zoopla.co.uk//for-sale/details/58012488/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('799950'), Decimal('2.0'), Decimal('1.0'), Decimal('2.0'), 'Meadvale Road, Ealing W5', Decimal('0.8'), 'Perivale'], [Decimal('58012484'), 'https://www.zoopla.co.uk//for-sale/details/58012484/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('725000'), Decimal('2.0'), Decimal('2.0'), Decimal('1.0'), 'Globe View, 10 High Timber Street, London EC4V', Decimal('0.1'), 'Bankside Pier'], [Decimal('58012481'), 'https://www.zoopla.co.uk//new-homes/details/58012481/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('2375000'), Decimal('3.0'), Decimal('3.0'), Decimal('1.0'), 'Paddington Gardens, North Wharf Road, London W2', Decimal('0.2'), 'Edgware Road Bakerloo'], [Decimal('58012483'), 'https://www.zoopla.co.uk//for-sale/details/58012483/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('500000'), Decimal('1.0'), Decimal('1.0'), Decimal('1.0'), "Clifford's Inn, Fetter Lane, London EC4A", Decimal('0.2'), 'Chancery Lane'], [Decimal('58012461'), 'https://www.zoopla.co.uk//for-sale/details/58012461/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('775000'), Decimal('2.0'), Decimal('1.0'), Decimal('1.0'), 'Woodlawn Close, London SW15', Decimal('0.2'), 'East Putney'], [Decimal('58012460'), 'https://www.zoopla.co.uk//for-sale/details/58012460/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('210000'), Decimal('1.0'), Decimal('1.0'), Decimal('1.0'), 'Longbridge Road, Essex IG11', Decimal('0.6'), 'Upney'], [Decimal('58012411'), 'https://www.zoopla.co.uk//for-sale/details/58012411/?search_identifier=a55179e261f8a7052e1f711e9890d0bf', Decimal('370000'), Decimal('2.0'), Decimal('2.0'), Decimal('1.0'), 'Kings Lodge, Pembroke Road, Ruislip, Middlesex HA4', Decimal('0.1'), 'Ruislip'], [Decimal('580123 ...
